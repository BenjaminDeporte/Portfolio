# %% [markdown]
# # EDA

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Load Data

# %%
filepath = '/home/benjamin/Folders_Python/Portfolio/BTC/data/extract/outputBTCUSDT-2021-1-1-2025-11-24-1d.csv'

data = pd.read_csv(filepath)
data['Open'] = pd.to_datetime(data['Open'])
data.set_index('Open', inplace=True)

# %%
data
# Out:
#                                    High       Low     Close         Volume  \
# Open
# 1970-01-01 00:00:00.000028923  29600.00  28624.57  29331.69   54182.925011
# 1970-01-01 00:00:00.000029331  33300.00  28946.53  32178.33  129993.873362
# 1970-01-01 00:00:00.000032176  34778.11  31962.99  33000.05  120957.566750
# 1970-01-01 00:00:00.000033000  33600.00  28130.00  31988.71  140899.885690
# 1970-01-01 00:00:00.000031989  34360.00  29900.00  33949.53  116049.997038
# ...                                 ...       ...       ...            ...
# 1970-01-01 00:00:00.000091554  93160.00  86100.00  86637.23   39733.190730
# 1970-01-01 00:00:00.000086637  87498.94  80600.00  85129.43   72256.126790
# 1970-01-01 00:00:00.000085129  85620.00  83500.00  84739.74   14193.932630
# 1970-01-01 00:00:00.000084739  88127.64  84667.57  86830.00   19734.464180
# 1970-01-01 00:00:00.000086830  88059.44  85825.84  86015.05    9767.643410
#
# ...

# %% [markdown]
# Transform data and check for stationarity
